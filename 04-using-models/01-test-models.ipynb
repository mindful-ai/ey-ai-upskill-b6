# %% [markdown]
# ### Huggingface

# %% [markdown]
# ##### Reading the API Key from the vault

# %%
path = r"E:\Lenovo Ideapad 330\company-material\digital-workforce-transformation\ai-upskill-5\key-vault\huggingface\api.key"

# %%
f = open(path, 'r')
api_key = f.read()
f.close()

# %%
api_key[:9]

# %%
#!pip install openai

# %%
import os
from openai import OpenAI

# %% [markdown]
# ###### Alternatively, we can use python's requests module for sending the HTTP request to the HF server

# %%
client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=api_key
)
client

# %%
response = client.chat.completions.create(
    model="Qwen/Qwen2.5-72B-Instruct:fastest",
    messages=[
        {"role": "system", "content":"You are a helpful and brief AI."},
        {"role": "user", "content": "Tell me 5 facts about Voyager 1"}
    ],
    max_tokens=500,
)

# %%
print(response.choices[0].message.content)

# %% [markdown]
# ### GROQ - https://groq.com/

# %%
# !pip install groq

# %% [markdown]
# ##### Using OpenAI Client

# %%
f = open(r"E:\Lenovo Ideapad 330\company-material\digital-workforce-transformation\ai-upskill-5\key-vault\groq\api.key")
groq_api_key = f.read()
f.close()

# %%
from groq import Groq

# %%
client = Groq(api_key=groq_api_key)

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "system", "content":"You are a helpful and brief AI."},
        {"role": "user", "content": "Tell me 5 facts about Voyager 1"}
    ],
    max_tokens=500,
)

# %%
print(response.choices[0].message.content)

# %%
from langchain_openai import OpenAI

# %%
llm = OpenAI(api_key=api_key)
